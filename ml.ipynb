# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Heart Attack Data Set.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['age'], bins=30, kde=True)
plt.xlabel('age')
plt.ylabel('Count')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
gender = df['sex'].value_counts()
labels = ['Male', 'Female']
colors = ['lightblue', 'lightpink']     
explode = [0.1, 0]  # explode the 1st slice (by 10%)
plt.pie(gender, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
column_mapping = {
    "age": "Age",
    "sex": "Sex",
    "cp": "Chest Pain Type",
    "trestbps": "Resting Blood Pressure",
    "chol": "Cholesterol",
    "fbs": "Fasting Blood Sugar",
    "restecg": "Resting ECG Results",
    "thalach": "Max Heart Rate Achieved",
    "exang": "Exercise Induced Angina",
    "oldpeak": "ST Depression",
    "slope": "ST Slope",
    "ca": "Number of Major Vessels",
    "thal": "Thalassemia",
    "target": "Heart Disease"
}

# %%
df.rename(columns=column_mapping, inplace=True)

# %%
df
# Out:
#      Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0     63    1                3                     145          233
# 1     37    1                2                     130          250
# 2     41    0                1                     130          204
# 3     56    1                1                     120          236
# 4     57    0                0                     120          354
# ..   ...  ...              ...                     ...          ...
# 298   57    0                0                     140          241
# 299   45    1                3                     110          264
# 300   68    1                0                     144          193
# 301   57    1                0                     130          131
# 302   57    0                1                     130          236
#
#      Fasting Blood Sugar  Resting ECG Results  Max Heart Rate Achieved  \
# 0                      1                    0                      150
# 1                      0                    1                      187
# 2                      0                    0                      172
# 3                      0                    1                      178
# 4                      0                    1                      163
# ..                   ...                  ...                      ...
# 298                    0                    1                      123
# 299                    0                    1                      132
# 300                    1                    1                      141
# 301                    0                    1                      115
# 302                    0                    0                      174
#
#      Exercise Induced Angina  ST Depression  ST Slope  \
# 0                          0            2.3         0
# 1                          0            3.5         0
# 2                          0            1.4         2
# 3                          0            0.8         2
# 4                          1            0.6         2
# ..                       ...            ...       ...
# 298                        1            0.2         1
# 299                        0            1.2         1
# 300                        0            3.4         1
# 301                        1            1.2         1
# 302                        0            0.0         1
#
#      Number of Major Vessels  Thalassemia  Heart Disease
# 0                          0            1              1
# 1                          0            2              1
# 2                          0            2              1
# 3                          0            2              1
# 4                          0            2              1
# ..                       ...          ...            ...
# 298                        0            3              0
# 299                        0            3              0
# 300                        2            3              0
# 301                        1            3              0
# 302                        1            2              0
#
# [303 rows x 14 columns]

# %%
sns.boxplot(x = "Max Heart Rate Achieved", data = df)
plt.show()

# %%
df[df['Max Heart Rate Achieved'] > 200]
# Out:
#     Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 72   29    1                1                     130          204
#
#     Fasting Blood Sugar  Resting ECG Results  Max Heart Rate Achieved  \
# 72                    0                    0                      202
#
#     Exercise Induced Angina  ST Depression  ST Slope  Number of Major Vessels  \
# 72                        0            0.0         2                        0
#
#     Thalassemia  Heart Disease
# 72            2              1

# %%
df = df[df['Max Heart Rate Achieved'] < 200]
df[df['Max Heart Rate Achieved'] > 200]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Chest Pain Type, Resting Blood Pressure, Cholesterol, Fasting Blood Sugar, Resting ECG Results, Max Heart Rate Achieved, Exercise Induced Angina, ST Depression, ST Slope, Number of Major Vessels, Thalassemia, Heart Disease]
# Index: []

# %%
df
# Out:
#      Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0     63    1                3                     145          233
# 1     37    1                2                     130          250
# 2     41    0                1                     130          204
# 3     56    1                1                     120          236
# 4     57    0                0                     120          354
# ..   ...  ...              ...                     ...          ...
# 298   57    0                0                     140          241
# 299   45    1                3                     110          264
# 300   68    1                0                     144          193
# 301   57    1                0                     130          131
# 302   57    0                1                     130          236
#
#      Fasting Blood Sugar  Resting ECG Results  Max Heart Rate Achieved  \
# 0                      1                    0                      150
# 1                      0                    1                      187
# 2                      0                    0                      172
# 3                      0                    1                      178
# 4                      0                    1                      163
# ..                   ...                  ...                      ...
# 298                    0                    1                      123
# 299                    0                    1                      132
# 300                    1                    1                      141
# 301                    0                    1                      115
# 302                    0                    0                      174
#
#      Exercise Induced Angina  ST Depression  ST Slope  \
# 0                          0            2.3         0
# 1                          0            3.5         0
# 2                          0            1.4         2
# 3                          0            0.8         2
# 4                          1            0.6         2
# ..                       ...            ...       ...
# 298                        1            0.2         1
# 299                        0            1.2         1
# 300                        0            3.4         1
# 301                        1            1.2         1
# 302                        0            0.0         1
#
#      Number of Major Vessels  Thalassemia  Heart Disease
# 0                          0            1              1
# 1                          0            2              1
# 2                          0            2              1
# 3                          0            2              1
# 4                          0            2              1
# ..                       ...          ...            ...
# 298                        0            3              0
# 299                        0            3              0
# 300                        2            3              0
# 301                        1            3              0
# 302                        1            2              0
#
# [302 rows x 14 columns]

# %%
import pandas as pd

categorical_cols = [
    'Sex', 'Chest Pain Type', 'Fasting Blood Sugar',
    'Resting ECG Results', 'Exercise Induced Angina',
    'ST Slope', 'Number of Major Vessels',
    'Thalassemia', 'Heart Disease'
]

result = []

for col in categorical_cols:
    vc = df[col].value_counts().reset_index()
    vc.columns = ['Value', 'Count']
    vc['Column'] = col
    result.append(vc)

final_df = pd.concat(result)

print(final_df.to_string(index=False))
# Out:
#  Value  Count                  Column
#      1    206                     Sex
#      0     96                     Sex
#      0    143         Chest Pain Type
#      2     87         Chest Pain Type
#      1     49         Chest Pain Type
#      3     23         Chest Pain Type
#      0    257     Fasting Blood Sugar
#      1     45     Fasting Blood Sugar
#      1    152     Resting ECG Results
#      0    146     Resting ECG Results
#      2      4     Resting ECG Results
#      0    203 Exercise Induced Angina
#      1     99 Exercise Induced Angina
#      2    141                ST Slope
#      1    140                ST Slope
#      0     21                ST Slope
#      0    174 Number of Major Vessels
#      1     65 Number of Major Vessels
#      2     38 Number of Major Vessels
#      3     20 Number of Major Vessels
#      4      5 Number of Major Vessels
#      2    165             Thalassemia
#      3    117             Thalassemia
#      1     18             Thalassemia
#      0      2             Thalassemia
#      1    164           Heart Disease
#      0    138           Heart Disease

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay,precision_score, recall_score, f1_score, roc_auc_score,roc_curve

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ["Heart Disease"])
y = df["Heart Disease"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)
X_train.shape, X_test.shape
# Out:
# ((226, 13), (76, 13))

# %%
models={
    "Decision Tree":DecisionTreeClassifier(),
    "Random Forest":RandomForestClassifier(),
    "Gradient Boost":GradientBoostingClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Xgboost":XGBClassifier()
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) 

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)


    model_train_accuracy = accuracy_score(y_train, y_train_pred) 
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred)
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') 
    model_test_precision = precision_score(y_test, y_test_pred) 
    model_test_recall = recall_score(y_test, y_test_pred) 
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred)


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

    
    print('='*35)
    print('\n')
# Out:
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7895
# - F1 score: 0.7898
# - Precision: 0.8205
# - Recall: 0.7805
# - Roc Auc Score: 0.7902
# ===================================
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8289
# - F1 score: 0.8291
# - Precision: 0.8500
# - Recall: 0.8293
# - Roc Auc Score: 0.8289
# ===================================
#
#
# Gradient Boost
# Model performance for Training set
# - Accuracy: 0.9956
# - F1 score: 0.9956
# - Precision: 0.9919
# - Recall: 1.0000
# - Roc Auc Score: 0.9951
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8289
# - F1 score: 0.8292
# - Precision: 0.8684
# - Recall: 0.8049
# - Roc Auc Score: 0.8310
# ===================================
#
#
# Adaboost
# Model performance for Training set
# - Accuracy: 0.9159
# - F1 score: 0.9158
# - Precision: 0.9127
# - Recall: 0.9350
# - Roc Auc Score: 0.9141
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8026
# - F1 score: 0.8028
# - Precision: 0.8250
# - Recall: 0.8049
# - Roc Auc Score: 0.8024
# ===================================
#
#
# Xgboost
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7895
# - F1 score: 0.7889
# - Precision: 0.7907
# - Recall: 0.8293
# - Roc Auc Score: 0.7861
# ===================================

# %%
rf = RandomForestClassifier(
    n_estimators=200,        
    max_depth=None,          
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1    )

# %%
# rf=RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:, 1]

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8289473684210527
# ROC-AUC: 0.9247386759581881
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82        35
#            1       0.87      0.80      0.84        41
#
#     accuracy                           0.83        76
#    macro avg       0.83      0.83      0.83        76
# weighted avg       0.83      0.83      0.83        76

# %%
import pickle

with open("random_forest_model.pkl", "wb") as f:
    pickle.dump(rf, f)

print("Model saved successfully ✅")
# Out:
# Model saved successfully ✅
